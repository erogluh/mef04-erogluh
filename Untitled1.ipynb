# %% [markdown]
# <a href="https://colab.research.google.com/github/erogluh/mef04-erogluh/blob/gh-pages/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Australia Rain Prediction**
#
# Firt, I will download the libraries that I will use when analyzing the data.

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Then, I will upload the file that I will use.

# %%
df = pd.read_csv("/weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...     21.8         No            No
# 1  2008-12-02   Albury      7.4  ...     24.3         No            No
# 2  2008-12-03   Albury     12.9  ...     23.2         No            No
# 3  2008-12-04   Albury      9.2  ...     26.5         No            No
# 4  2008-12-05   Albury     17.5  ...     29.7         No            No
#
# [5 rows x 23 columns]

# %% [markdown]
# To visulize and manipulete the data. I will do some preprocessing works on data.

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp  ...        Temp9am       Temp3pm
# count  143975.000000  144199.000000  ...  143693.000000  141851.00000
# mean       12.194034      23.221348  ...      16.990631      21.68339
# std         6.398495       7.119049  ...       6.488753       6.93665
# min        -8.500000      -4.800000  ...      -7.200000      -5.40000
# 25%         7.600000      17.900000  ...      12.300000      16.60000
# 50%        12.000000      22.600000  ...      16.700000      21.10000
# 75%        16.900000      28.200000  ...      21.600000      26.40000
# max        33.900000      48.100000  ...      40.200000      46.70000
#
# [8 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
zeros_cnt = df.isnull().sum().sort_values(ascending=False)
percent_zeros = (df.isnull().sum() / df.isnull().count()).sort_values(ascending=False)

missing_data = pd.concat([zeros_cnt, percent_zeros], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                Total   Percent
# Sunshine       69835  0.480098
# Evaporation    62790  0.431665
# Cloud3pm       59358  0.408071
# Cloud9am       55888  0.384216
# Pressure9am    15065  0.103568
# Pressure3pm    15028  0.103314
# WindDir9am     10566  0.072639
# WindGustDir    10326  0.070989
# WindGustSpeed  10263  0.070555
# Humidity3pm     4507  0.030984
# WindDir3pm      4228  0.029066
# Temp3pm         3609  0.024811
# RainTomorrow    3267  0.022460
# RainToday       3261  0.022419
# Rainfall        3261  0.022419
# WindSpeed3pm    3062  0.021050
# Humidity9am     2654  0.018246
# WindSpeed9am    1767  0.012148
# Temp9am         1767  0.012148
# MinTemp         1485  0.010209
# MaxTemp         1261  0.008669
# Location           0  0.000000
# Date               0  0.000000

# %%
dropList = list(missing_data[missing_data['Percent'] > 0.15].index)
dropList
df.drop(dropList, axis=1, inplace=True)

# %%
df['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
df.shape
# Out:
# (145460, 19)

# %%
sns.pairplot(df[:1000])

# %%
ohe = pd.get_dummies(data=df, columns=['WindGustDir','WindDir9am','WindDir3pm'])
ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 64 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date             145460 non-null  object
#  1   Location         145460 non-null  object
#  2   MinTemp          143975 non-null  float64
#  3   MaxTemp          144199 non-null  float64
#  4   Rainfall         142199 non-null  float64
#  5   WindGustSpeed    135197 non-null  float64
#  6   WindSpeed9am     143693 non-null  float64
#  7   WindSpeed3pm     142398 non-null  float64
#  8   Humidity9am      142806 non-null  float64
#  9   Humidity3pm      140953 non-null  float64
#  10  Pressure9am      130395 non-null  float64
#  11  Pressure3pm      130432 non-null  float64
#  12  Temp9am          143693 non-null  float64
#  13  Temp3pm          141851 non-null  float64
#  14  RainToday        142199 non-null  object
#  15  RainTomorrow     142193 non-null  object
#  16  WindGustDir_E    145460 non-null  uint8
#  17  WindGustDir_ENE  145460 non-null  uint8
#  18  WindGustDir_ESE  145460 non-null  uint8
#  19  WindGustDir_N    145460 non-null  uint8
#  20  WindGustDir_NE   145460 non-null  uint8
#  21  WindGustDir_NNE  145460 non-null  uint8
#  22  WindGustDir_NNW  145460 non-null  uint8
#  23  WindGustDir_NW   145460 non-null  uint8
#  24  WindGustDir_S    145460 non-null  uint8
#  25  WindGustDir_SE   145460 non-null  uint8
#  26  WindGustDir_SSE  145460 non-null  uint8
#  27  WindGustDir_SSW  145460 non-null  uint8
#  28  WindGustDir_SW   145460 non-null  uint8
#  29  WindGustDir_W    145460 non-null  uint8
#  30  WindGustDir_WNW  145460 non-null  uint8
#  31  WindGustDir_WSW  145460 non-null  uint8
#  32  WindDir9am_E     145460 non-null  uint8
#  33  WindDir9am_ENE   145460 non-null  uint8
#  34  WindDir9am_ESE   145460 non-null  uint8
#  35  WindDir9am_N     145460 non-null  uint8
#  36  WindDir9am_NE    145460 non-null  uint8
#  37  WindDir9am_NNE   145460 non-null  uint8
#  38  WindDir9am_NNW   145460 non-null  uint8
#  39  WindDir9am_NW    145460 non-null  uint8
#  40  WindDir9am_S     145460 non-null  uint8
#  41  WindDir9am_SE    145460 non-null  uint8
#  42  WindDir9am_SSE   145460 non-null  uint8
#  43  WindDir9am_SSW   145460 non-null  uint8
#  44  WindDir9am_SW    145460 non-null  uint8
#  45  WindDir9am_W     145460 non-null  uint8
#  46  WindDir9am_WNW   145460 non-null  uint8
#  47  WindDir9am_WSW   145460 non-null  uint8
#  48  WindDir3pm_E     145460 non-null  uint8
#  49  WindDir3pm_ENE   145460 non-null  uint8
#  50  WindDir3pm_ESE   145460 non-null  uint8
#  51  WindDir3pm_N     145460 non-null  uint8
#  52  WindDir3pm_NE    145460 non-null  uint8
#  53  WindDir3pm_NNE   145460 non-null  uint8
#  54  WindDir3pm_NNW   145460 non-null  uint8
#  55  WindDir3pm_NW    145460 non-null  uint8
#  56  WindDir3pm_S     145460 non-null  uint8
#  57  WindDir3pm_SE    145460 non-null  uint8
#  58  WindDir3pm_SSE   145460 non-null  uint8
#  59  WindDir3pm_SSW   145460 non-null  uint8
#  60  WindDir3pm_SW    145460 non-null  uint8
#  61  WindDir3pm_W     145460 non-null  uint8
#  62  WindDir3pm_WNW   145460 non-null  uint8
#  63  WindDir3pm_WSW   145460 non-null  uint8
# dtypes: float64(12), object(4), uint8(48)
# memory usage: 24.4+ MB

# %%
from sklearn import preprocessing
from numpy import array

ohe['RainToday'] = df['RainToday'].astype(str)
ohe['RainTomorrow'] = df['RainTomorrow'].astype(str)

lb = preprocessing.LabelBinarizer()

ohe['RainToday'] = lb.fit_transform(ohe['RainToday'])
ohe['RainTomorrow'] = lb.fit_transform(ohe['RainTomorrow'])

# %%
ohe = ohe.dropna()
#ohe.drop('Location', axis=1, inplace=True)
y = ohe['RainTomorrow']
X = ohe.drop(['RainTomorrow'], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84266 entries, 115490 to 82879
# Data columns (total 63 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             84266 non-null  object
#  1   Location         84266 non-null  object
#  2   MinTemp          84266 non-null  float64
#  3   MaxTemp          84266 non-null  float64
#  4   Rainfall         84266 non-null  float64
#  5   WindGustSpeed    84266 non-null  float64
#  6   WindSpeed9am     84266 non-null  float64
#  7   WindSpeed3pm     84266 non-null  float64
#  8   Humidity9am      84266 non-null  float64
#  9   Humidity3pm      84266 non-null  float64
#  10  Pressure9am      84266 non-null  float64
#  11  Pressure3pm      84266 non-null  float64
#  12  Temp9am          84266 non-null  float64
#  13  Temp3pm          84266 non-null  float64
#  14  RainToday        84266 non-null  int64
#  15  WindGustDir_E    84266 non-null  uint8
#  16  WindGustDir_ENE  84266 non-null  uint8
#  17  WindGustDir_ESE  84266 non-null  uint8
#  18  WindGustDir_N    84266 non-null  uint8
#  19  WindGustDir_NE   84266 non-null  uint8
#  20  WindGustDir_NNE  84266 non-null  uint8
#  21  WindGustDir_NNW  84266 non-null  uint8
#  22  WindGustDir_NW   84266 non-null  uint8
#  23  WindGustDir_S    84266 non-null  uint8
#  24  WindGustDir_SE   84266 non-null  uint8
#  25  WindGustDir_SSE  84266 non-null  uint8
#  26  WindGustDir_SSW  84266 non-null  uint8
#  27  WindGustDir_SW   84266 non-null  uint8
#  28  WindGustDir_W    84266 non-null  uint8
#  29  WindGustDir_WNW  84266 non-null  uint8
#  30  WindGustDir_WSW  84266 non-null  uint8
#  31  WindDir9am_E     84266 non-null  uint8
#  32  WindDir9am_ENE   84266 non-null  uint8
#  33  WindDir9am_ESE   84266 non-null  uint8
#  34  WindDir9am_N     84266 non-null  uint8
#  35  WindDir9am_NE    84266 non-null  uint8
#  36  WindDir9am_NNE   84266 non-null  uint8
#  37  WindDir9am_NNW   84266 non-null  uint8
#  38  WindDir9am_NW    84266 non-null  uint8
#  39  WindDir9am_S     84266 non-null  uint8
#  40  WindDir9am_SE    84266 non-null  uint8
#  41  WindDir9am_SSE   84266 non-null  uint8
#  42  WindDir9am_SSW   84266 non-null  uint8
#  43  WindDir9am_SW    84266 non-null  uint8
#  44  WindDir9am_W     84266 non-null  uint8
#  45  WindDir9am_WNW   84266 non-null  uint8
#  46  WindDir9am_WSW   84266 non-null  uint8
#  47  WindDir3pm_E     84266 non-null  uint8
#  48  WindDir3pm_ENE   84266 non-null  uint8
#  49  WindDir3pm_ESE   84266 non-null  uint8
#  50  WindDir3pm_N     84266 non-null  uint8
#  51  WindDir3pm_NE    84266 non-null  uint8
#  52  WindDir3pm_NNE   84266 non-null  uint8
#  53  WindDir3pm_NNW   84266 non-null  uint8
#  54  WindDir3pm_NW    84266 non-null  uint8
#  55  WindDir3pm_S     84266 non-null  uint8
#  56  WindDir3pm_SE    84266 non-null  uint8
#  57  WindDir3pm_SSE   84266 non-null  uint8
#  58  WindDir3pm_SSW   84266 non-null  uint8
#  59  WindDir3pm_SW    84266 non-null  uint8
#  60  WindDir3pm_W     84266 non-null  uint8
#  61  WindDir3pm_WNW   84266 non-null  uint8
#  62  WindDir3pm_WSW   84266 non-null  uint8
# dtypes: float64(12), int64(1), object(2), uint8(48)
# memory usage: 14.1+ MB
